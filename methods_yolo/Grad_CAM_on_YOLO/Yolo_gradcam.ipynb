# %%
import os
os.chdir(r'C:\Users\Lenovo\PycharmProjects\pythonProject1\content\yolov5-gradcam')

# %%
#python content/yolov5-gradcam/main.py --model-path F:\Models_data\Yolo_v5\Small\best.pt --img-path F:\Models_data\project_2\Test\images\fed1305d-4_5-1.png --output-dir file_output --names 'Fully Tight Screw','Loose Screw','Missing Screw'
# Out:
#   Cell In[17], line 1
#     python content/yolov5-gradcam/main.py --model-path F:\Models_data\Yolo_v5\Small\best (2).pt --img-path F:\Models_data\project_2\Test\images\fc7a5e68-54_10.png --output-dir file_output --names 'Fully Tight Screw','Loose Screw','Missing Screw'
#            ^
# SyntaxError: invalid syntax

# %%
# Out:
#   Cell In[8], line 1
#     python main.py
#            ^
# SyntaxError: invalid syntax

# %%
#(   "F:\Models_data\project_2\Test\images\eca3a9ae-57_4_1.png"
#    "F:\Models_data\project_2\Test\images\e63049e4-55_6_1.png"
#    "F:\Models_data\project_2\Test\images\fc7a5e68-54_10_1.png"
#    "F:\Models_data\project_2\Test\images\edb67c20-32_6_1.png"
#    "F:\Models_data\project_2\Test\images\fcc24328-29_10-1.png"
#    "F:\Models_data\project_2\Test\images\f249ec88-11_4_1.png"
#    "F:\Models_data\project_2\Test\images\f49dabb9-8_10_1.png"
#    "F:\Models_data\project_2\Test\images\f55b6573-6_3_1.png"
#    "F:\Models_data\project_2\Test\images\f40de274-5_1_1.png"
#    "F:\Models_data\project_2\Test\images\fed1305d-4_5-1.png" )
